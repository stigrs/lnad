# %%
import network_analysis.analysis as network
import network_analysis.geonetwork as geonetwork

# %%
grid = geonetwork.GeoNetwork("railway.shp")

# %%
grid.plot(add_basemap=True)
# Out:
# <Axes: xlabel='East', ylabel='North'>

# %%
topology = network.NetworkAnalysis(grid.graph)
dc = topology.betweenness_centrality()
print(dc)
# Out:
# {(568593.2500000009, 6622809.470000001, 6.380000000004657): 0.008522727272727272, (568803.2400000012, 6622811.199999997, 3.5100000000056752): 0.008522727272727272, (594655.7901000008, 6590983.9812, 4.93934800000352): 0.005681818181818182, (611858.1070000017, 6565424.7453000005, 7.310948000005737): 0.005681818181818182, (598469.8672000011, 6640705.033300001, 6.397248000004765): 0.005681818181818182, (603367.7173000015, 6622201.625600001, 129.46984800000428): 0.005681818181818182, (601092.8416999998, 6616242.1241, 97.65864800000418): 0.005681818181818182, (621646.1538000004, 6572699.228600003, 40.94094799999948): 0.005681818181818182, (641333.3106000023, 6556499.408299997, 92.65734800000428): 0.005681818181818182, (641884.8101000013, 6550439.786600001, 160.78564800000458): 0.005681818181818182, (597971.0831000013, 6642837.277899999, -0.4684759999945527): 0.005681818181818182, (588668.5200000005, 6642585.3500000015, -11.250023500004318): 0.005681818181818182, (579915.6513999999, 6632830
# ...
