# %%
import igraph as ig
import lnad.analysis as lnad
import lnad.geonetwork as geonetwork

# %%
grid = geonetwork.GeoNetwork("railway.shp")

# %%
grid.plot(add_basemap=True)
# Out:
# <Axes: xlabel='East', ylabel='North'>

# %%
topology = lnad.NetworkAnalysis(grid.get_igraph())
dc = topology.degree_centrality()
print(dc)
# Out:
# {igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 290, {'_nx_name': (568593.2500000009, 6622809.470000001, 6.380000000004657)}): 0.008522727272727272, igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 291, {'_nx_name': (568803.2400000012, 6622811.199999997, 3.5100000000056752)}): 0.008522727272727272, igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 0, {'_nx_name': (594655.7901000008, 6590983.9812, 4.93934800000352)}): 0.005681818181818182, igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 1, {'_nx_name': (611858.1070000017, 6565424.7453000005, 7.310948000005737)}): 0.005681818181818182, igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 2, {'_nx_name': (598469.8672000011, 6640705.033300001, 6.397248000004765)}): 0.005681818181818182, igraph.Vertex(<igraph.Graph object at 0x000001228EBA7750>, 3, {'_nx_name': (603367.7173000015, 6622201.625600001, 129.46984800000428)}): 0.005681818181818182, igraph.Vertex(<igraph.Graph object at 0x00000122
# ...
